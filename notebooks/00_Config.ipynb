# %% [markdown]
# ## Initial Setup
#
# <div class="alert" style="background-color:#ff103f; color: #ffffff"><strong>Note:</strong> Before running this notebook, follow the <strong><a href="setup.ipynb" style="color: #d1e8ff">local setup instructions</a></strong>. </div>
#
# After completing the initial setup instructions, run this notebook to finalize the environment configuration.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import logging
import ipytest
from pathlib import Path

# %%
from src.paths import DATA_DIR

# --- Constants ---
DATA_DIR.mkdir(parents=True, exist_ok=True)
